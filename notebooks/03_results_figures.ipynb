# %% [markdown]
# # 03 — Results Figures
#
# Reproduce paper-style figures: enrichment landscape heatmap, hit-rate
# per sublibrary with bootstrap CIs, and the confusion matrix comparing
# transformer predictions to the CNN's 4-class labels.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nucb_transformer.training.metrics import confusion_matrix_df, bootstrap_hit_rate
from nucb_transformer.data.encoding import ACTIVITY_CLASSES

# %%
# Confusion matrix
# cm = confusion_matrix_df(preds, labels)
# sns.heatmap(cm, annot=True, fmt='d', xticklabels=ACTIVITY_CLASSES, yticklabels=ACTIVITY_CLASSES)
# plt.title('Transformer vs. true activity class')

# %%
# Hit-rate with bootstrap CIs per sublibrary
# for sublibrary, group in results.groupby('sublibrary'):
#     lo, hi = bootstrap_hit_rate(group.pred.values, group.label.values)
#     print(f'{sublibrary}: {lo:.3f} – {hi:.3f}')
